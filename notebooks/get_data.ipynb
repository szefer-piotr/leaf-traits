# %%
# import os
import fsspec
# import zipfile 
from pathlib import Path
# Out:
# Did not find data/01_raw/train_images directory, downloading from GitHub...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 16
#      14 print(f"Did not find {image_path} directory, downloading from GitHub...")
#      15 fs = fsspec.filesystem("github", org="szefer-piotr", repo="leaf_trait_data")
# ---> 16 fs.get(fs.ls(""), data_path.as_posix(), recursive=True)
#
# File ~/.cache/pypoetry/virtualenvs/leaf-traits-1EnC7LYy-py3.10/lib/python3.10/site-packages/fsspec/spec.py:976, in AbstractFileSystem.get(self, rpath, lpath, recursive, callback, maxdepth, **kwargs)
#     974 for lpath, rpath in callback.wrap(zip(lpaths, rpaths)):
#     975     with callback.branched(rpath, lpath) as child:
# --> 976         self.get_file(rpath, lpath, callback=child, **kwargs)
#
# ...
